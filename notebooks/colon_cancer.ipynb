# %%
from func import *

# %%
datasets = {
    'mirna': 'data/colon/Merged_RNASeq_20230703-234755/Merged_miRNA_Counts.tsv',
    'mrna': 'data/colon/Merged_RNASeq_20230703-234755/Merged_mRNA_Counts.tsv'
}

label = 'data/colon/mmc2.xlsx'

# %%
# Load data
def load_data(dataset, subtypes, target_name, dataset_sheet_name=None, subtype_sheet_name=None):    

    if subtypes.endswith(".xlsx"):
        subtypes = pd.read_excel(subtypes, sheet_name=subtype_sheet_name, header=1, index_col=0)
    else:
        subtypes = pd.read_csv(subtypes, sep='\t', index_col=0)
    
    if dataset.endswith(".xlsx"):
        df = pd.read_excel(dataset, sheet_name=dataset_sheet_name)
    else:
        df = pd.read_csv(dataset, sep='\t')

    df = df.transpose()

    new_header = df.iloc[0] #grab the first row for the header
    df = df[1:] #take the data less the header row
    df.columns = new_header #set the header row as the df header
    print(df)
    #print(subtypes)

    data = pd.concat([df, subtypes[[target_name]]], axis=1, join="inner")

    data.columns = data.columns.str.strip()
    data[target_name] = correct_dtypes(data[target_name])

    return data

# %%
subtypes = pd.read_excel(label, sheet_name='Supplemental Table S1D', header=1, index_col=0)
subtypes
# Out:
# /Users/signehoel/comp401/sklearn-venv/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                 ALL_SAMPLES      MUTATIONSUBTYPES ALL_PRIMARY_VS_METASTATIC  \
# Name
# TCGA-BF-A1PU-01         Yes  BRAF_Hotspot_Mutants             All_Primaries
# TCGA-BF-A1PV-01         Yes   RAS_Hotspot_Mutants             All_Primaries
# TCGA-BF-A1PX-01         Yes  BRAF_Hotspot_Mutants             All_Primaries
# TCGA-BF-A1PZ-01         Yes   RAS_Hotspot_Mutants             All_Primaries
# TCGA-BF-A1Q0-01         Yes             Triple_WT             All_Primaries
# ...                     ...                   ...                       ...
# TCGA-GN-A26A-06         Yes             Triple_WT            All_Metastases
# TCGA-GN-A26C-01         Yes       NF1_Any_Mutants             All_Primaries
# TCGA-GN-A26D-06         Yes             Triple_WT            All_Metastases
# ...

# %%
mirna = load_data(datasets['mirna'], label, 'MUTATIONSUBTYPES', subtype_sheet_name='Supplemental Table S1D')
# Out:
# /Users/signehoel/comp401/sklearn-venv/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Unnamed: 0                   hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3  \
# TCGA-FR-A7U8-06A-21R-A358-13        59082        59278        59231
# TCGA-WE-AAA4-06A-12R-A38N-13       100785       101057       100799
# TCGA-D3-A8GS-06A-12R-A37G-13        36578        36643        36859
# TCGA-D3-A2JB-06A-11R-A18W-13        46003        45528        46327
# TCGA-DA-A1I5-06A-11R-A18W-13        31658        31315        32244
# ...                                   ...          ...          ...
# TCGA-EB-A3XC-01A-11R-A23A-13        51808        51461        51481
# TCGA-RP-A6K9-06A-41R-A358-13        47317        47332        47687
# TCGA-GF-A769-01A-32R-A360-13        28586        28324        28663
# TCGA-QB-A6FS-06A-11R-A310-13        42075        42049        42140
# ...

# %%
mirna
# Out:
# Empty DataFrame
# ...

# %%
subtypes = pd.read_excel(label, sheet_name='Supplemental Table S1D', header=1)
    
if dataset.endswith(".xlsx"):
        df = pd.read_excel(dataset, sheet_name=dataset_sheet_name)
else:
        df = pd.read_csv(dataset, sep='\t')

df = df.transpose()

new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

data = pd.concat([df, subtypes], axis=1, join="inner")

data.columns = data.columns.str.strip()
data[target_name] = correct_dtypes(data[target_name])

# %%
import rpy2.robjects as ro

# Load R data using the R command 'load'
ro.r('load("path_to_your_r_data_file.RData")')

# Access the R object from Python
r_dataframe = ro.r['r_data_frame']

# Convert the R data frame to a pandas DataFrame
pandas_dataframe = pd.DataFrame(r_dataframe)

# Now you can work with the pandas DataFrame
print(pandas_dataframe.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import rpy2.robjects as ro
#       3 # Load R data using the R command 'load'
#       4 ro.r('load("path_to_your_r_data_file.RData")')
#
# ModuleNotFoundError: No module named 'rpy2'
